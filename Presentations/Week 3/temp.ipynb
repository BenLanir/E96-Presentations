# %%
# Download pandas and sklearn
# !pip install pandas
# !pip install sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=30116ac69a52af6f0b42c3e3a6aa9fd80e171709aa7c6ef6491d6e0893804ece
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# ...

# %%
# Load libraries
import numpy as np # You should understand this line
import matplotlib.pyplot as plt # You should understand this line
import pandas as pd # PANDAS!!!

# %%
def mse (y1, y2):
  error = 0.0
  for i, j in zip(y1, y2):
    error += (i - j)**2
  error = error / len(y1)
  return error

# %%
# mount Google Drive
# This code connects this jupyter notebook with all the files in your google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
lists = pd.read_csv('/content/gdrive/Shareddrives/ENGR 96: Python and Machine Learning/In-Class Labs/line_fitting.csv')

# %%
x = lists.x

# %%
import random

random.seed(10)
m = random.uniform(1.5, 2.5)
b = random.uniform(0, 4)
num_points = 100
x1 = [random.uniform(0, 10) for i in range(num_points)]
y1 = [random.uniform(m*x+b - 3, m*x+b + 3) for x in x1]

plt.scatter(x1, y1, color = 'orange')

x2 = np.arange(0, 10, 0.01)
y2 = 2 * x2

#plt.plot(x2, y2)

y3 = 2 * np.array(x1) + 1

plt.plot(x2, best_beta1 * np.array(x2) + best_beta0)

print(mse(y1, y3))
# Out:
# 4.235388468345236

# %%
best_beta0 = 0
best_beta1 = 1
best_mse = mse(best_beta1 * np.array(x1) + best_beta0, y1)
for i in np.arange(0, 5, 0.01):
  for j in np.arange(0, 5, 0.01):
    mse_temp = mse(i * np.array(x1) + j, y1)
    if mse_temp < best_mse:
      best_mse = mse_temp
      best_beta0 = j
      best_beta1 = i
print(best_mse)
# Out:
# 2.655187023106517

# %%
polybeta0, polybeta1 = np.polyfit(x1, y1, 1)

plt.plot(x2, polybeta1 * np.array(x2) + polybeta0)

# %%
for i, j in zip(x1, y1):
  print(str(i) + ',' + str(j))
# Out:
# 5.780913011344704,10.70713699017078
# 2.0609823213950174,6.197191054745416
# 8.1332125135732,15.866151373413038
# 8.235888725334455,16.331857925988803
# 6.534725339011757,12.904141717277149
# 1.6022955651881965,4.759025391984348
# 5.206693596399246,15.456843238619735
# 3.2777281162209313,8.415382848159005
# 2.4999667668640035,6.645835569071416
# 9.528169091459116,21.071295284615818
# 9.965569925394552,22.364936728780034
# 0.4455638245043303,2.3210230965228345
# 8.60161037286291,20.89024546696033
# 6.0319061096818505,16.597711398985297
# 3.8160598591911787,10.807374596547694
# 2.8361821790671513,7.13029495943989
# 6.74964847134956,16.593970284922996
# 4.568311510583056,13.63561212021601
# 6.858614854745947,13.844272874015966
# 6.618463200523511,13.849112806524833
# 1.329781447122128,5.184740959326548
# 7.678378139439905,18.742688293635496
# 9.824132490111909,22.920891085566424
# 9.693881604049189,22.326659103334734
# 6.13326820546709,16.39656305650636
# ...
